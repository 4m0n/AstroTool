# %%
import pandas as pd
import numpy as np
from astropy.timeseries import LombScargle
import scipy.signal as signal
import random
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("../astro_tool"))
print(sys.path)
import models.synthetic_base as bs
# Out:
# ['/Users/amon/Documents/Apps/Python/astro_tool/models', '/opt/anaconda3/envs/astro_tool/lib/python312.zip', '/opt/anaconda3/envs/astro_tool/lib/python3.12', '/opt/anaconda3/envs/astro_tool/lib/python3.12/lib-dynload', '', '/opt/anaconda3/envs/astro_tool/lib/python3.12/site-packages', '/Users/amon/Documents/Apps/Python/astro_tool', '/Users/amon/Documents/Apps/Python/astro_tool/astro_tool']

# %%
Curve = bs.SYNTHETIC(noise = 1)
Curve.create_gabs()
Curve.simple_sin(A=10,b=365*20)
Curve.simple_sin(A=2,b=200)

#Curve.simple_sin(2)

# %%
Curve.FourierLombScargle(True)
# Out:
# $\displaystyle 10.00 \cdot \sin\!\left(\frac{2\pi}{7300.00\,\text{d}} \, x\right)+2.00 \cdot \sin\!\left(\frac{2\pi}{200.00\,\text{d}} \, x\right)$
# Formula: None
# Sin times in days:
# [7300.0, 200.0]
# Top 3 Peaks:
#            time  frequency  properties
# 0  10428.571429   0.000096    0.751123
# 1    412.429379   0.002425    0.232766
# 2    330.316742   0.003027    0.224027

# %%
bs.freq_analysis(A = 1, noise = 1, start_time=0.2, end_time=20)
