# %%
import pandas as pd
import numpy as np
from astropy.timeseries import LombScargle
import scipy.signal as signal
import random
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath("../astro_tool"))
print(sys.path)
import models.synthetic_base as bs
# Out:
# ['/Users/amon/Documents/Apps/Python/astro_tool/models', '/opt/anaconda3/envs/astro_tool/lib/python312.zip', '/opt/anaconda3/envs/astro_tool/lib/python3.12', '/opt/anaconda3/envs/astro_tool/lib/python3.12/lib-dynload', '', '/opt/anaconda3/envs/astro_tool/lib/python3.12/site-packages', '/Users/amon/Documents/Apps/Python/astro_tool', '/Users/amon/Documents/Apps/Python/astro_tool/astro_tool', '/Users/amon/Documents/Apps/Python/astro_tool/astro_tool']

# %%
Curve = bs.SYNTHETIC(noise = 1)
Curve.create_gabs()
Curve.simple_sin(A=4,b=365*20)
#Curve.simple_sin(A=2,b=200)

#Curve.simple_sin(2)

# %%
#Curve.FourierLombScargle(True)
T = Curve.fit_sin(plot=True)

print((2*np.pi/T)/(24*60*60*365))
print(Curve.fitted_sin)
# Out:
# Fit sinus: 6861.292370652527d
# 18.79806128945898
# [np.float64(6861.292370652527), np.float64(3.606194157266995)]

# %%
bs.freq_analysis(A = 1, noise = 1, start_time=0.2, end_time=20)
# Out:
# <div id='c6e84138-8d9a-42c4-a87d-21fccde8be07'></div>

# %%
CurvePeak = bs.SYNTHETIC(noise = 1)
#CurvePeak.create_gabs()
CurvePeak.create_peak(width = 100)
CurvePeak.create_peak(width = 100,position=500)

CurvePeak.simple_sin()
CurvePeak.plot()
CurvePeak.fprint()
# Out:
# <div id='6a74803a-5afa-4432-b8ab-ecdb417fdd35'></div>
# $\displaystyle 5.00\,\exp\!\left(-\frac{\left(x-5.00\,\mathrm{yr}\right)^2}{2\left(\frac{100.00\,\mathrm{d}}{2\sqrt{2\ln 2}}\right)^2}\right) + 5.00\,\exp\!\left(-\frac{\left(x-1.37\,\mathrm{yr}\right)^2}{2\left(\frac{100.00\,\mathrm{d}}{2\sqrt{2\ln 2}}\right)^2}\right)+0.78 \cdot \sin\!\left(\frac{2\pi}{1854.27\,\text{d}} \, x\right)$
# Formula: None
